# %% [markdown]
# # Monte Carlo Simulation with Stock

# %%
import pandas as pd
import pandas_datareader as web
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start = "2018-01-01"
end = datetime.today().strftime("%Y-%m-%d")

# %%
df = web.DataReader("ECV.DE", data_source="yahoo", start = start, end = end)

# %%
df

# %%
plt.figure(figsize=(16,8))
plt.plot(df["Adj Close"])

# %%
last_price = df["Adj Close"][-1]
print(last_price)

# %%
returns = df["Adj Close"].pct_change()
print(returns)

# %%
daily_vol = returns.std()

# %%
num_simulations = 100
num_days = 50

# %%
simulation_df = pd.DataFrame()
price_series = []

for i in range(num_simulations):
    price_series.clear()
    counter = 0
    price = last_price * (1 + np.random.normal(0, daily_vol))
    price_series.append(price)
    
    for x in range(num_days):
        if counter == 251:
            break
        
        price = price_series[counter] * (1 + np.random.normal(0, daily_vol))
        price_series.append(price)
        counter += 1
        
    simulation_df[i] = price_series

# %%
simulation_df

# %%
plt.figure(figsize=(16,8))
plt.plot(simulation_df)
plt.axhline(df["Adj Close"][-1], color="r")
plt.show
